# %% [markdown]
# <a href="https://colab.research.google.com/github/Aulfadhli/Data-Science_W1/blob/main/Datasets_IDS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opendatasets

# %%
import opendatasets as od
od.download("https://www.kaggle.com/datasets/anassarfraz13/student-success-factors-and-insights")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: aulfadhli
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/anassarfraz13/student-success-factors-and-insights
# ...
# 100%|██████████| 93.9k/93.9k [00:00<00:00, 55.5MB/s]

# %%
import pandas as pd
data = pd.read_csv("/content/student-success-factors-and-insights/StudentPerformanceFactors.csv")

# %%
data.head(7000)
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# # **Tutorial 3 Questions**
# 2. Evaluate if the data is good or not. Does it have enough samples? <br>
# -> Yes the data is good, it has more than 6000 samples
#
# 3. How many features does it have? Is it enough? <br>
# -> The dataset has 20 features(columns). This is a good number of features for analyzing the factors of student's success
# 4. How many samples/observation does it have? Is it enough? <br>
# -> There are over 6000 samples/observation, for research purposes it is more than enough to conclude the necessary factors of student's success
# 5. What are the datatypes does the dataset consist of? <br>
# -> The dataset consists of multiple datatypes, such as:
#     - Numerical: Hours_studied, Attendance, Sleep_hours, Previous_Scores, Tutoring_Sessions, Physical_Activity, Exam_Score
#     - Categorical(Ordinal): Gender, School_Type, Internet_Access, Learning_Disability
#     - Categorical(Continous): Motivation_Level, Peer_Influence, Parental_Education_Level, Family_Income, Access_to_Resources, Teacher_Quality, Parental_Involvement
#   6. How many columns have null values? If yes, which column, which rows<br>
#   -> No columns have null values, all 20 columns on every observation each have a value
#   7. Which column is the feature, which is the target output?<br>
#   -> The target output is the one that the dataset is trying to predict, which is the exam score of students,<br>
#   -> Features (inputs) are then all the other variables (hours studied, attendance, parental involvement, etc) that might influence the target output
#   8. Does it have missing values? If yes, which column, which row.<br>
#   -> No, the dataset does not have any missing value in each of the rows and columns
#   9. What kind of question can be asked, should we ask. Does the dataset suits the question we are asking? <br>
#   -> Descriptive Questions (What happened?):"What is the average GPA of successful vs unsuccessful students?" <br>
#   -> Diagnostic Question (Why did it happen?): "Why do some students perform better than others?" <br>
#   -> Predictive Question (What will happen?): "Can we predict a student's exam score based on their study habits and attendance?" <br>
#   -> Prescriptive Question (What should we do?): "What actions can students take to improve their performance?"
